# %%
import cv2, dlib
import numpy as np
from imutils import face_utils
from tensorflow.keras.models import load_model
import time
#import RPI.GPIO as GPIO

# %%
IMG_SIZE = (34, 26)

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# %%
model = load_model('model.h5')
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 26, 34, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 34, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 17, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               786944
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 880,129
# Trainable params: 880,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
def crop_eye(img, eye_points):
    x1, y1 = np.amin(eye_points, axis=0)
    x2, y2 = np.amax(eye_points, axis=0)
    cx, cy = (x1 + x2) / 2, (y1 + y2) / 2

    w = (x2 - x1) * 1.2
    h = w * IMG_SIZE[1] / IMG_SIZE[0]

    margin_x, margin_y = w / 2, h / 2

    min_x, min_y = int(cx - margin_x), int(cy - margin_y)
    max_x, max_y = int(cx + margin_x), int(cy + margin_y)

    eye_rect = np.rint([min_x, min_y, max_x, max_y]).astype(np.int)
  
    eye_img = gray[eye_rect[1]:eye_rect[3], eye_rect[0]:eye_rect[2]]

    return eye_img, eye_rect

# main
cap = cv2.VideoCapture(0)

'''            
def LED_on(pin):#ex18번 핀에 끼운 led 센서를 키기
    GPIO.setmode(GPIO.BOARD)
    GPIO.setup(pin, GPIO.OUT)
    
    GPIO.output(pin,True)
    
    GPIO.cleanup(pin)
  
'''
blink_time = 0.0

while cap.isOpened():
    ret, img_ori = cap.read()

    if not ret:
        break

    img_ori = cv2.resize(img_ori, dsize=(0, 0), fx=0.5, fy=0.5)

    img = img_ori.copy()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    faces = detector(gray)

    for face in faces:
        shapes = predictor(gray, face)
        shapes = face_utils.shape_to_np(shapes)

        eye_img_l, eye_rect_l = crop_eye(gray, eye_points=shapes[36:42])
        eye_img_r, eye_rect_r = crop_eye(gray, eye_points=shapes[42:48])

        eye_img_l = cv2.resize(eye_img_l, dsize=IMG_SIZE)
        eye_img_r = cv2.resize(eye_img_r, dsize=IMG_SIZE)
        eye_img_r = cv2.flip(eye_img_r, flipCode=1)

        #cv2.imshow('l', eye_img_l)
        #cv2.imshow('r', eye_img_r)

        eye_input_l = eye_img_l.copy().reshape((1, IMG_SIZE[1], IMG_SIZE[0], 1)).astype(np.float32) / 255.
        eye_input_r = eye_img_r.copy().reshape((1, IMG_SIZE[1], IMG_SIZE[0], 1)).astype(np.float32) / 255.

        pred_l = model.predict(eye_input_l)
        pred_r = model.predict(eye_input_r)

        # visualize
        state_l = 'O %.1f' if pred_l > 0.1 else '- %.1f'
        state_r = 'O %.1f' if pred_r > 0.1 else '- %.1f'

        state_l = state_l % pred_l
        state_r = state_r % pred_r

        cv2.rectangle(img, pt1=tuple(eye_rect_l[0:2]), pt2=tuple(eye_rect_l[2:4]), color=(255,255,255), thickness=2)
        cv2.rectangle(img, pt1=tuple(eye_rect_r[0:2]), pt2=tuple(eye_rect_r[2:4]), color=(255,255,255), thickness=2)

        cv2.putText(img, state_l, tuple(eye_rect_l[0:2]), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)
        cv2.putText(img, state_r, tuple(eye_rect_r[0:2]), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)

        if state_r and state_l == '- 0.0':
            print("눈감음")
            blink_time = time.time()
        else :
            if time.time() - blink_time >7: #눈감은 순간부터 
                print("7초이상 눈떳음. 눈을 깜빡이세요.")
                #LED_on(18) #라즈베리파이 led센서 키기

    cv2.imshow('result', img)
    if cv2.waitKey(1) == ord('q'):
        break
# Out:
# 눈감음
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 7초이상 눈떳음. 눈을 깜빡이세요.
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# 눈감음
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0c8e0984ec79> in <module>
#      63         eye_input_r = eye_img_r.copy().reshape((1, IMG_SIZE[1], IMG_SIZE[0], 1)).astype(np.float32) / 255.
#      64
# ---> 65         pred_l = model.predict(eye_input_l)
#      66         pred_r = model.predict(eye_input_r)
#      67
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1567     with self.distribute_strategy.scope():
#    1568       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1569       data_handler = data_adapter.DataHandler(
#    1570           x=x,
#    1571           batch_size=batch_size,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1103
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#    1107         y,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     360       return flat_dataset
#     361
# --> 362     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     363
#     364     dataset = self.slice_inputs(indices_dataset, inputs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func)
#    1725       Dataset: A `Dataset`.
#    1726     """
# -> 1727     return FlatMapDataset(self, map_func)
#    1728
#    1729   def interleave(self,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func)
#    4127               type(self._map_func.output_structure)))
#    4128     self._structure = self._map_func.output_structure._element_spec  # pylint: disable=protected-access
# -> 4129     variant_tensor = gen_dataset_ops.flat_map_dataset(
#    4130         input_dataset._variant_tensor,  # pylint: disable=protected-access
#    4131         self._map_func.function.captured_inputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, name)
#    2025   if tld.is_eager:
#    2026     try:
# -> 2027       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2028         _ctx._context_handle, tld.device_name, "FlatMapDataset", name,
#    2029         tld.op_callbacks, input_dataset, other_arguments, "f", f,
#
# KeyboardInterrupt:
